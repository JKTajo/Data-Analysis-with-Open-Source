# %% [markdown]
# <a href="https://colab.research.google.com/github/JKTajo/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_15%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 15강 시계열 데이터 분석 : 주가 데이터 활용
#
# ### 목표
#
# - S&P500 지수를 중심으로 주가 데이터를 수집
# - 다양한 시계열 분석 기법을 적용하여 의미 있는 인사이트를 도출
#
# > ⚠️**주의**⚠️ : 이번 장에서 다루는 내용은 순전히 교육 및 실습 목적으로 주가 데이터를 활용하는 것이며, 실제 투자 결정을 위한 가이드로 사용할 수 없다. 시계열 분석 기법은 과거 데이터의 패턴을 학습하는 데 유용하나, 금융 시장의 불확실성과 예측 불가능한 사건들로 인해 실제 투자에 적용할 경우 상당한 위험이 따를 수 있다. 어떤 분석 방법도 미래 주가를 완벽히 예측할 수 없으며, 본 내용은 데이터 분석 기술을 배우는 학습 도구로만 활용하길 권장한다.
#
# ### 분석 프로세스 개요
#
# 1. 데이터 수집
#   - yfinance를 이용한 데이터 수집
#   - 데이터 구조 이해
# 2. 금융 시계열 분석
#   - 기술적 지표 계산 (이동평균, RSI)
#   - 거래 신호 생성 및 거래 전략 구성
#   - 백테스팅
# 3. Prophet 기반 예측
#   - 단기 주가 예측 모델 학습 및 평가
# 4. GBRT 기반 예측
#   - 특성 변수 설계 및 예측 모델 학습
#   - 예측 기반 투자 전략 및 백테스팅

# %%
# 한글 처리를 위한 matplotlib 설정 (1)

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache –fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,872 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# - 런타임 -> 세션 다시 시작

# %%
# 한글 처리를 위한 matplotlib 설정 (2)

import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # 1. 데이터 수집

# %% [markdown]
# ## 15-1 yfinance를 이용한 S&P 500 데이터 다운로드

# %%
# yfinance 임포트
import yfinance as yf
import datetime

symbol = 'S&P500'
ticker = '^GSPC'

## 데이터 수집 날짜 설정 (2014년 1월 1일) ~ (2019년 12월 31일)
start_date = datetime.datetime(2002, 1, 1)
end_date = datetime.datetime(2007, 12, 31)

## yfinance를 사용하여 S&P 500 (^GSPC) 데이터를 지정된 기간 동안 다운로드
df = yf.download(ticker, start=start_date, end=end_date)

## MultiIndex 컬럼에서 두 번째 레벨(보통 'Adj Close' 등)을 제거하여 컬럼 이름을 단순화
df.columns = df.columns.droplevel(1)

## 다운로드된 DataFrame의 기술 통계량 출력
df.describe()
# Out:
# /tmp/ipython-input-160668080.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price        Close         High          Low         Open        Volume
# count  1509.000000  1509.000000  1509.000000  1509.000000  1.509000e+03
# mean   1180.308198  1186.915713  1173.087953  1180.076336  1.961649e+09
# std     189.154888   188.594514   189.567822   189.007583  7.821436e+08
# min     776.760010   798.549988   768.630005   776.760010  3.560700e+08
# 25%    1058.410034  1063.020020  1052.170044  1058.410034  1.396500e+09
# 50%    1173.800049  1178.869995  1168.699951  1173.780029  1.679500e+09
# 75%    1295.430054  1300.780029  1291.400024  1295.369995  2.424720e+09
# max    1565.150024  1576.089966  1555.459961  1564.979980  6.509300e+09

# %% [markdown]
# ## 15-2 S&P 500 데이터 시각화 (훈련/테스트 분할)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.grid(True)
plt.title('S&P500')
## 2018년까지의 데이터를 훈련 데이터로 시각화
plt.plot(df[:'2006'].index, df[:'2006']['Close'], label='Train Data')
## 2018년 이후 데이터를 훈련 데이터로 시각화
plt.plot(df['2006':].index, df['2006':]['Close'], label='Test Data')
plt.legend()
plt.show()

# %% [markdown]
# # 2. 금융 시계열 분석

# %% [markdown]
# ## 15-3 기술 지표 계산

# %%
## 50일 이동 평균 계산
df['MA50'] = df['Close'].rolling(window=50).mean()
## 200일 이동 평균 계산
df['MA200'] = df['Close'].rolling(window=200).mean()


## 일별 수익률 계산
df['Returns'] = df['Close'].pct_change()

## RSI 계산
delta = df['Close'].diff()
gain = delta.where(delta > 0, 0).rolling(window=14).mean()
loss = -delta.where(delta < 0, 0).rolling(window=14).mean()
rs = gain / loss
df['RSI'] = 100 - (100 / (1 + rs))

# %% [markdown]
# ## 15-4 기본 차트 생성 및 시각화

# %%
def make_base_chart(df, title, show_close_only=False):
  ## 기본 차트(종가, 이동평균선, RSI)를 생성하는 함수
  fig, ax1 = plt.subplots(figsize=(10, 6))

  ax1.plot(df.index, df['Close'], label='Close')
  ax1.set_title(title)
  ax1.set_ylabel('Price')
  ax1.grid(True)
  ax1.legend(loc='upper left')

  if not show_close_only:
    ## 종가만 표시하지 않을 경우
    ax2 = ax1.twinx()
    ax1.plot(df.index, df['MA50'], label='MA50')
    ax1.plot(df.index, df['MA200'], label='MA200')
    ax2.plot(df.index, df['RSI'], 'red', label='RSI', alpha=0.5, linewidth=1)
    ax2.set_ylabel('RSI')
    ax2.set_ylim(0, 100)  # RSI는 0-100 범위
    ax2.legend(loc='upper right')

  return fig, ax1

## 테스트 데이터셋 (2018년 이후)에 대해 기본 차트 시각화
test_df = df['2006':]
fig, ax1 = make_base_chart(test_df, 'S&P500 이동평균선과 RSI')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 15-5 매수/매도 신호 생성

# %% [markdown]
# 매수/매도 신호 절감

# %%
import pandas as pd

def make_signal(df):
  ## 이동평균선과 RSI를 기반으로 매수/매도 신호를 생성하는 함수
    #buy = ( (test_df['MA50'] > test_df['MA200']) & (test_df['MA50'].shift(1) <= test_df['MA200'].shift(1)) |
         ## MA 골든 크로스 (현재 시점에서 50일 이동 평균이 200일 이동 평균보다 위에 있다. & 이전 시점에서는 50일 이동 평균이 200일 이동 평균보다 같거나 아래에 있었다.)
        #(test_df['RSI'] > 30) & (test_df['RSI'].shift(1) <= 30))   ## RSI 30 상향 돌파

    buy = (
    (
        ((test_df['MA50'] > test_df['MA200']) &
         (test_df['MA50'].shift(1) <= test_df['MA200'].shift(1))) |
        ((test_df['RSI'] > 35) &
         (test_df['RSI'].shift(1) <= 35))
    )
    &
    (test_df['Close'] > test_df['MA200'])  # 장기 상승장 필터
)

    sell = ( (test_df['MA50'] < test_df['MA200']) & (test_df['MA50'].shift(1) >= test_df['MA200'].shift(1)) |
          ## MA 데드 크로스 (현재 시점에서 50일 이동 평균이 200일 이동 평균보다 아래에 있다. & 이전 시점에서는 50일 이동 평균이 200일 이동 평균보다 같거나 위에 있었다.)
          (test_df['RSI'] < 70) & (test_df['RSI'].shift(1) >= 70)) ## RSI 70 하향 돌파


    return buy, sell

## 테스트 데이터셋에 대해 매수/매도 신호 생성
test_df = df['2006':].copy()
buy, sell = make_signal(test_df)

# %%
def make_signal(df):

    # -----------------
    # 📈 BUY 조건
    # -----------------
    buy = (
        (
            (
                (df['MA50'] > df['MA200']) &
                (df['MA50'].shift(1) <= df['MA200'].shift(1))
            )
            |
            (
                (df['RSI'] > 35) &
                (df['RSI'].shift(1) <= 35)
            )
        )
        &
        (df['Close'] > df['MA200'])   # 장기 상승장 필터
    )

    # -----------------
    # 📉 SELL 조건
    # -----------------

    # 1️⃣ MA 데드크로스
    ma_sell = (
        (df['MA50'] < df['MA200']) &
        (df['MA50'].shift(1) >= df['MA200'].shift(1))
    )

    # 2️⃣ RSI 70 하향돌파
    rsi_cross = (
        (df['RSI'] < 70) &
        (df['RSI'].shift(1) >= 70)
    )

    # 3️⃣ 최근 20일 최고가 근처 (98% 이상)
    rolling_high = df['Close'].rolling(20).max()
    high_condition = df['Close'] >= rolling_high * 0.98

    rsi_sell = rsi_cross & high_condition

    # 최종 sell
    sell = ma_sell | rsi_sell

    # 4️⃣ 연속 sell 방지
    sell = sell & (~sell.shift(1).fillna(False))

    return buy, sell
test_df = df['2006':].copy()
buy, sell = make_signal(test_df)
# Out:
# /tmp/ipython-input-1285486559.py:48: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sell = sell & (~sell.shift(1).fillna(False))

# %%
print("Buy count:", buy.sum())
print("Sell count:", sell.sum())
buy
# Out:
# Buy count: 8
# Sell count: 27
# Date
# 2006-01-03    False
# 2006-01-04    False
# 2006-01-05    False
# 2006-01-06    False
# 2006-01-09    False
#               ...
# 2007-12-21    False
# 2007-12-24    False
# 2007-12-26    False
# 2007-12-27    False
# 2007-12-28    False
# Length: 501, dtype: bool

# %% [markdown]
# ## 15-6 매수/매도 신호 시각화

# %%
def plot_signal(df, buy, sell):
  ## 매수/매도 신호를 차트에 표시하는 함수
  fig, ax1 = make_base_chart(df, "S&P500 구매 및 판매 시그널") ## 기본 차트 생성

  ## 매수/매도 신호 날짜 추출
  buy_dates = df.index[buy]
  sell_dates = df.index[sell] ## 매도 신호 날짜 추출

  ## 매수/매도 신호 산점도로 표시
  ax1.scatter(buy_dates, df.loc[buy_dates, 'Close'], marker='^', color='g', s=100, label='Buy Signal')
  ax1.scatter(sell_dates, df.loc[sell_dates, 'Close'], marker='v', color='r', s=100, label='Sell Signal')

  # 범례 업데이트
  handles, labels = ax1.get_legend_handles_labels()
  ax1.legend(handles=handles, labels=labels, loc='upper left')

  return fig, ax1

fig, ax1 = plot_signal(test_df, buy, sell)
plt.show()

# %% [markdown]
# ## 15-7 거래 포지션 생성 및 시각화

# %%
def make_and_plot_position(df, buy, sell):
    ## 거래 포지션(보유/미보유)을 생성하고 차트에 시각화하는 함수

    ## DataFrame 인덱스로 새로운 'position' DataFrame 생성
    position = pd.DataFrame(index=df.index)
    ## 매수 시 signal 1, 매도 시 signal 0 할당
    position.loc[buy, 'signal'] = 1
    position.loc[sell, 'signal'] = 0

    ## 신호를 하루 뒤로 밀어 포지션 시작 시점 반영
    position = position['signal'].shift(1)

    # 처음 상태는 0(미보유)로 시작
    position['position'] = position.ffill().fillna(0)

    ## 기본 차트 생성
    fig, ax1 = make_base_chart(df, 'S&P500 거래 포지션')

    for i in range(len(df)-1):
        ## 포지션이 1(보유)인 경우 초록색 음영 생성
        if position['position'].iloc[i] == 1:
            ax1.axvspan(df.index[i], df.index[i+1], alpha=0.1, color='green')
        ## 포지션이 0(미보유)인 경우 빨간색 음영 생성
        else:
            ax1.axvspan(df.index[i], df.index[i+1], alpha=0.1, color='red')

    # 범례 업데이트
    handles, labels = ax1.get_legend_handles_labels()
    ax1.legend(handles=handles, labels=labels, loc='upper left')

    return position

## 거래 포지션 생성 및 시각화
position = make_and_plot_position(test_df, buy, sell)

# %% [markdown]
# ## 15-8 백테스트 및 수익률 분석

# %%
def backtest(df, position):
    ## 일별 수익률 사용 (이미 계산된 값)
    daily_returns = df['Returns']

    ## 1) Buy & Hold 전략의 누적 수익률
    buy_hold_returns = (1 + daily_returns).cumprod() - 1

    ## 2) 포지션에 따른 전략의 수익률
    strategy_returns = daily_returns * position['position']

    ## 누적 수익률 계산
    strategy_cumulative_returns = (1 + strategy_returns).cumprod() - 1

    final_buy_hold_return = buy_hold_returns.iloc[-1] * 100
    final_strategy_return = strategy_cumulative_returns.iloc[-1] * 100

    print(f"Buy & Hold 최종 수익률: {final_buy_hold_return:.2f}%")
    print(f"전략 최종 수익률: {final_strategy_return:.2f}%")

    ## 수익률 추이 그래프 시각화
    plt.figure(figsize=(12, 6))
    plt.plot(buy_hold_returns.index, buy_hold_returns * 100, label='Buy & Hold', color='blue')
    plt.plot(strategy_cumulative_returns.index, strategy_cumulative_returns * 100, label='Strategy', color='green')
    plt.xlabel('Date')
    plt.ylabel('Return (%)')
    plt.title('Buy & Hold vs. Strategy Returns')
    plt.legend()
    plt.grid(True)
    plt.show()

backtest(test_df, position)
# Out:
# Buy & Hold 최종 수익률: 18.44%
# 전략 최종 수익률: 13.44%

# %% [markdown]
# # 3. Prophet 기반 예측

# %% [markdown]
# ## 15-9 Prophet 예측 및 시각화

# %%
# prophet 모듈에서 Prophet 클래스 임포트
from prophet import Prophet

def prophet_prediction(df, periods=5):
    ## Prophet 모델을 사용하여 시계열 데이터를 예측하는 함수

    ## Prophet 형식에 맞게 DataFrame 준비
    # prophet은 ds와 y 칼럼 필요. df의 인덱스를 해제하고, Date와 Close 칼럼만 선택한 다음, Date를 ds로, Close를 y로 변환하여 prophet_df로 저장.
    prophet_df = df.reset_index()[['Date', 'Close']].rename(columns={'Date': 'ds', 'Close': 'y'})
    ## Prophet 모델 훈련
    model = Prophet()
    model.fit(prophet_df)

    ## 미래 예측
    future = model.make_future_dataframe(periods=periods)
    forecast = model.predict(future)
    return model, forecast

## 훈련 데이터 셋 생성
train_df = df[:'2006']
## 훈련 데이터로 향후 365일 예측
model, forecast = prophet_prediction(train_df, periods=365)

## 예측 결과 및 시계열 구성 요소 시각화
fig1 = model.plot(forecast)
plt.show()
fig2 = model.plot_components(forecast)
plt.show()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py:197: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumBarunGothic.
#   fig.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumBarunGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 15-10 확장 윈도우 예측

# %%
def expanding_window_forecast(train_df, test_df, step_size=30):
    ## 확장 윈도우 방식으로 Prophet 모델을 사용하여 예측을 수행하는 함수
    # 30일 간격으로 새로운 모델을 생성하고 예측
    result_df = test_df.copy()
    # prophet 결과 칼럼 추가
    for col in ['yhat', 'yhat_upper', 'yhat_lower']:
        result_df[col] = None

    current_train = train_df.copy()

    ## 테스트 데이터셋을 step_size 간격으로 순회
    for i in range(0, len(test_df), step_size):
        ## 테스트 기간 설정
        current_test = test_df.iloc[i:min(i + step_size, len(test_df))]
        ## 최근 365일 훈련 데이터로 Prophet 예측 수행
        _, forecast = prophet_prediction(current_train[-365:], periods=len(current_test))

        ## 예측 결과를 저장
        for j, date in enumerate(current_test.index):
            for col in ['yhat', 'yhat_upper', 'yhat_lower']:
                result_df.loc[date, col] = forecast.tail(len(current_test)).iloc[j][col]

        ## 훈련 데이터 셋 확장
        current_train = pd.concat([current_train, current_test])

    return result_df

## 확장 윈도우 예측 수행 (2018년까지 훈련, 2018년 이후 테스트)
prophet_df = df.copy()
prophet_prediction_df = expanding_window_forecast(prophet_df[:'2006'], prophet_df['2006':])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet_df
# Out:
# Price             Close         High          Low         Open      Volume  \
# Date
# 2002-01-02  1154.670044  1154.670044  1136.229980  1148.079956  1171000000
# 2002-01-03  1165.270020  1165.270020  1154.010010  1154.670044  1398900000
# 2002-01-04  1172.510010  1176.550049  1163.420044  1165.270020  1513000000
# 2002-01-07  1164.890015  1176.969971  1163.550049  1172.510010  1308300000
# 2002-01-08  1160.709961  1167.599976  1157.459961  1164.890015  1258800000
# ...                 ...          ...          ...          ...         ...
# 2007-12-21  1484.459961  1485.400024  1463.189941  1463.189941  4508590000
# 2007-12-24  1496.449951  1497.630005  1484.550049  1484.550049  1267420000
# 2007-12-26  1497.660034  1498.849976  1488.199951  1495.119995  2010500000
# 2007-12-27  1476.270020  1495.050049  1475.859985  1495.050049  2365770000
# 2007-12-28  1478.489990  1488.010010  1471.699951  1479.829956  2420510000
#
# Price              MA50        MA200   Returns        RSI
# Date
# 2002-01-02          NaN          NaN       NaN        NaN
# 2002-01-03          NaN          NaN  0.009180        NaN
# 2002-01-04          NaN          NaN  0.006213        NaN
# 2002-01-07          NaN          NaN -0.006499        NaN
# 2002-01-08          NaN          NaN -0.003588        NaN
# ...                 ...          ...       ...        ...
# 2007-12-21  1486.843599  1488.325750  0.016670  52.976352
# 2007-12-24  1485.536597  1488.774999  0.008077  58.224996
# 2007-12-26  1484.515598  1489.373550  0.000809  53.444813
# 2007-12-27  1483.270398  1489.819050 -0.014282  41.495599
# 2007-12-28  1482.015398  1490.250099  0.001504  42.818707
#
# [1509 rows x 9 columns]

# %%
prophet_prediction_df
# Out:
# Price             Close         High          Low         Open      Volume  \
# Date
# 2006-01-03  1268.800049  1270.219971  1245.739990  1248.290039  2554570000
# 2006-01-04  1273.459961  1275.369995  1267.739990  1268.800049  2515330000
# 2006-01-05  1273.479980  1276.910034  1270.300049  1273.459961  2433340000
# 2006-01-06  1285.449951  1286.089966  1273.479980  1273.479980  2446560000
# 2006-01-09  1290.150024  1290.780029  1284.819946  1285.449951  2301490000
# ...                 ...          ...          ...          ...         ...
# 2007-12-21  1484.459961  1485.400024  1463.189941  1463.189941  4508590000
# 2007-12-24  1496.449951  1497.630005  1484.550049  1484.550049  1267420000
# 2007-12-26  1497.660034  1498.849976  1488.199951  1495.119995  2010500000
# 2007-12-27  1476.270020  1495.050049  1475.859985  1495.050049  2365770000
# 2007-12-28  1478.489990  1488.010010  1471.699951  1479.829956  2420510000
#
# Price              MA50        MA200   Returns        RSI         yhat  \
# Date
# 2006-01-03  1242.165203  1210.914399  0.016430  55.323748  1430.827699
# 2006-01-04  1244.042603  1211.362799  0.003673  53.953006  1431.921716
# 2006-01-05  1245.524602  1211.871649  0.000016  50.521267  1438.716496
# 2006-01-06  1247.302800  1212.436249  0.009399  58.940251  1438.791639
# 2006-01-09  1249.278201  1213.029899  0.003656  63.881846  1441.561023
# ...                 ...          ...       ...        ...          ...
# 2007-12-21  1486.843599  1488.325750  0.016670  52.976352  1499.101038
# 2007-12-24  1485.536597  1488.774999  0.008077  58.224996  1499.177456
# 2007-12-26  1484.515598  1489.373550  0.000809  53.444813  1496.825875
# 2007-12-27  1483.270398  1489.819050 -0.014282  41.495599  1497.482206
# 2007-12-28  1482.015398  1490.250099  0.001504  42.818707  1500.077607
#
# Price        yhat_upper   yhat_lower
# Date
# 2006-01-03  1443.918345  1416.488809
# 2006-01-04  1446.758359  1418.563537
# 2006-01-05  1452.707838  1424.784617
# 2006-01-06  1452.525831  1424.421515
# 2006-01-09  1454.911618   1427.06311
# ...                 ...          ...
# 2007-12-21  1529.881794  1467.660708
# 2007-12-24  1532.028787  1467.193908
# 2007-12-26    1528.9817  1466.114147
# 2007-12-27  1529.124384   1466.29695
# 2007-12-28  1530.586387  1468.985085
#
# [501 rows x 12 columns]

# %% [markdown]
# ## 15-11 예측 결과 시각화

# %%
def plot_prediction(df_with_predictions, model='Prophet'):
    ## 예측 결과를 실제 종가와 함께 시각화하는 함수
    fig, ax1 = make_base_chart(df_with_predictions, f'S&P500 이동평균선, RSI, {model} 예측 값', show_close_only=True)
    ## 예측값(yhat) 플로팅
    ax1.plot(df_with_predictions.index, df_with_predictions['yhat'], label='yhat', color='orange', linestyle='--')
    handles, labels = ax1.get_legend_handles_labels()
    ax1.legend(handles=handles, labels=labels, loc='upper left')
    plt.tight_layout()
    plt.show()

plot_prediction(prophet_prediction_df, model='Prophet')

# %% [markdown]
# # 4. GBRT 기반 예측

# %% [markdown]
# ## 15-12 Gradient Boosting Regressor 예측

# %%
# scikit learn의 ensemble 알고리즘 중 GradientBoostingRegresoor 임포트
from sklearn.ensemble import GradientBoostingRegressor

def expanding_window_forecast_gbrt(train_df, test_df, step_size=30):
    ## Gradient Boosting Regressor를 이용한 확장 윈도우 예측 함수

    ## 지연 피처 생성을 위한 훈련 및 테스트 데이터 결합
    combined = pd.concat([train_df, test_df])
    ## 피처 목록, (피처)_(지연일자)
    features = ['High_1', 'Low_1', 'Volume_1', 'MA50_1', 'MA200_1', 'Close_1', 'Close_2', 'Close_3', 'Close_4', 'Close_5', 'Close_6', 'Close_7']
    for feature in features:
        feature_column, lag = feature.split('_')  ## 피처 이름과 지연(lag) 분리
        combined[feature] = combined[feature_column].shift(int(lag))  ## 지연 피처 생성

    ## 학습 데이터, 훈련 데이터 재분리
    train = combined.loc[train_df.index]
    test = combined.loc[test_df.index]

    ## GBRT 모델 초기화
    # n_estimators=100, lr=0.1, max_depth=3, random_state=42로 설정
    model = GradientBoostingRegressor(n_estimators = 100, learning_rate = 0.1, max_depth = 3, random_state = 42)

    ## 예측 값 저장 칼럼 초기화
    test_df['yhat'] = None

    current_train = train.copy()
    ## 테스트 데이터셋을 step_size 간격으로 순회
    for start in range(0, len(test), step_size):
        ## 현재 테스트 윈도우 설정
        test_window = test.iloc[start:start+step_size]

        ## 최근 365일을 훈련 데이터로 설정
        train_data = current_train[-365:].dropna(subset=features + ['Close'])
        X_train, y_train = train_data[features], train_data['Close']

        ## 모델 학습
        model.fit(X_train, y_train)
        test_df.loc[test_window.index, 'yhat'] = model.predict(test_window[features])

        ## 훈련 데이터 확장
        current_train = pd.concat([current_train, test_window])

    return test_df

gbrt_df = df.copy()
## GBRT 확장 윈도우 예측 수행 (2018년까지 훈련, 2018년 이후 테스트)
gbrt_prediction_df = expanding_window_forecast_gbrt(gbrt_df[:'2006'], gbrt_df['2006':])
# Out:
# /tmp/ipython-input-1448712708.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['yhat'] = None

# %% [markdown]
# ## 15-13 GBRT 예측 결과 시각화

# %%
plot_prediction(gbrt_prediction_df, model='GBRT')

# %% [markdown]
# ## 15-14 예측값을 활용한 매수/매도 신호 생성

# %%
def make_signal_with_prediction(df):
    buy = (
        (df['MA50'] > df['MA200']) & (df['MA50'].shift(1) <= df['MA200'].shift(1)) |
        (df['RSI'] > 30) & (df['RSI'].shift(1) <= 30) |
        # 추가된 조건: 예측값이 현재 종가보다 높음 (상승 예측)
        (df['yhat'] > df['Close'] * 1.01)  # 1% 이상 상승 예측
    )

    sell = (
        (df['MA50'] < df['MA200']) & (df['MA50'].shift(1) >= df['MA200'].shift(1)) |
        (df['RSI'] < 70) & (df['RSI'].shift(1) >= 70) |
        # 옵션: 예측값이 현재 종가보다 낮음 (하락 예측)
        (df['yhat'] < df['Close'] * 0.99)  # 1% 이상 하락 예측
    )

    return buy, sell

buy, sell = make_signal_with_prediction(gbrt_prediction_df)

# %% [markdown]
# ## 15-15 예측값을 포함한 신호 시각화

# %%
fig, ax1 = plot_signal(gbrt_prediction_df, buy, sell)
ax1.plot(gbrt_prediction_df.index, gbrt_prediction_df['yhat'], label='yhat', color='orange', linestyle='--')
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles=handles, labels=labels, loc='upper left')
plt.show()

# %% [markdown]
# ## 15-16 예측 기반 거래 포지션 생성 및 시각화

# %%
position = make_and_plot_position(gbrt_prediction_df, buy, sell)

# %% [markdown]
# ## 15-17 예측 기반 전략 백테스트 실행

# %%
backtest(gbrt_prediction_df, position)
# Out:
# Buy & Hold 최종 수익률: 18.44%
# 전략 최종 수익률: 20.54%

# %%
import numpy as np

print("\n--- Comparing strategies for 2016 to present ---\n")

#기간설정, 가장최근데이터까지
new_start_date = datetime.datetime(2016, 1, 1)
new_end_date = datetime.datetime.now()

ticker = '^GSPC'
df_new = yf.download(ticker, start=new_start_date, end=new_end_date)
df_new.columns = df_new.columns.droplevel(1)
#전날 대비 종가가 몇% 변했는지 계산해서 Returns컬럼으로 추가
df_new['Returns'] = df_new['Close'].pct_change()#percentage change

#필요 데이터 다운로드
gold_ticker = 'GLD'
bonds_ticker = 'TLT'
commodities_ticker = 'DBC'


gld_df_new = yf.download(gold_ticker, start=new_start_date, end=new_end_date)
tlt_df_new = yf.download(bonds_ticker, start=new_start_date, end=new_end_date)
dbc_df_new = yf.download(commodities_ticker, start=new_start_date, end=new_end_date)

#멀티 컬럼에서 컬럼하나 탈락
gld_df_new.columns = gld_df_new.columns.droplevel(1)
tlt_df_new.columns = tlt_df_new.columns.droplevel(1)
dbc_df_new.columns = dbc_df_new.columns.droplevel(1)

# Close열 rename하고 해당 열만 새로 df로 저장
df_sp500_close_new = df_new.rename(columns={'Close': 'SP500_Close'})[['SP500_Close']]
gld_df_close_new = gld_df_new.rename(columns={'Close': 'GLD_Close'})[['GLD_Close']]
tlt_df_close_new = tlt_df_new.rename(columns={'Close': 'TLT_Close'})[['TLT_Close']]
dbc_df_close_new = dbc_df_new.rename(columns={'Close': 'DBC_Close'})[['DBC_Close']]

#새로 지정한 df들을 옆으로 붙인다
portfolio_df_new = pd.concat([df_sp500_close_new, gld_df_close_new, tlt_df_close_new, dbc_df_close_new], axis=1)
portfolio_df_new = portfolio_df_new.ffill().bfill()

#(오늘가격 - 어제가격) / 어제 가격, 1일차는 전날가격이 없으니까 드랍
portfolio_returns_new = portfolio_df_new.pct_change().dropna()


weights = {
    'SP500_Close': 0.60,
    'TLT_Close': 0.25,
    'GLD_Close': 0.075,
    'DBC_Close': 0.075
}
asset_weights = pd.Series(weights)


all_weather_portfolio_returns_new = (portfolio_returns_new * asset_weights).sum(axis=1)


#S&P500을 들고있었을때 수익률
sp500_buy_hold_returns_new = (1 + df_new['Returns']).cumprod() - 1 #cumprod는 cumulative product 누적곱, 즉 복리

#all weather포트폴리오 수익률, 위와 동일
all_weather_cumulative_returns_new = (1 + all_weather_portfolio_returns_new).cumprod() - 1

#위 둘의 비교 시각화
plt.figure(figsize=(14, 7))
plt.plot(sp500_buy_hold_returns_new.index, sp500_buy_hold_returns_new * 100, label='S&P 500 Buy & Hold', color='blue')
plt.plot(all_weather_cumulative_returns_new.index, all_weather_cumulative_returns_new * 100, label='All Weather Portfolio', color='purple')

plt.xlabel('Date')
plt.ylabel('Cumulative Return (%)')
plt.title(f'Cumulative Returns: S&P 500 Buy & Hold vs. All Weather Portfolio ({new_start_date.strftime('%Y-%m-%d')} to {new_end_date.strftime('%Y-%m-%d')[:10]})')
plt.legend()
plt.grid(True)
plt.show()

print(f"\nFinal S&P 500 Buy & Hold Cumulative Return ({new_start_date.strftime('%Y-%m-%d')} to {new_end_date.strftime('%Y-%m-%d')[:10]}): {sp500_buy_hold_returns_new.iloc[-1] * 100:.2f}%")
print(f"Final All Weather Portfolio Cumulative Return ({new_start_date.strftime('%Y-%m-%d')} to {new_end_date.strftime('%Y-%m-%d')[:10]}): {all_weather_cumulative_returns_new.iloc[-1] * 100:.2f}%")
# Out:
# --- Comparing strategies for 2016 to present ---
# /tmp/ipython-input-2155355325.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_new = yf.download(ticker, start=new_start_date, end=new_end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-2155355325.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gld_df_new = yf.download(gold_ticker, start=new_start_date, end=new_end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-2155355325.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tlt_df_new = yf.download(bonds_ticker, start=new_start_date, end=new_end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-2155355325.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   dbc_df_new = yf.download(commodities_ticker, start=new_start_date, end=new_end_date)
# [*********************100%***********************]  1 of 1 completed
# Final S&P 500 Buy & Hold Cumulative Return (2016-01-01 to 2026-02-20): 240.94%
# Final All Weather Portfolio Cumulative Return (2016-01-01 to 2026-02-20): 166.48%

# %%
#매수/매도 빈도율 절감

import pandas as pd

def make_signal(df):
  ## 이동평균선과 RSI를 기반으로 매수/매도 신호를 생성하는 함수
  buy = ( (test_df['MA50'] > test_df['MA200']) & (test_df['MA50'].shift(1) <= test_df['MA200'].shift(1)) &
         ## MA 골든 크로스 (현재 시점에서 50일 이동 평균이 200일 이동 평균보다 위에 있다. & 이전 시점에서는 50일 이동 평균이 200일 이동 평균보다 같거나 아래에 있었다.)
        (test_df['RSI'] > 30) & (test_df['RSI'].shift(1) <= 30)) ## RSI 30 상향 돌파

  sell = ( (test_df['MA50'] < test_df['MA200']) & (test_df['MA50'].shift(1) >= test_df['MA200'].shift(1)) &
          ## MA 데드 크로스 (현재 시점에서 50일 이동 평균이 200일 이동 평균보다 아래에 있다. & 이전 시점에서는 50일 이동 평균이 200일 이동 평균보다 같거나 위에 있었다.)
          (test_df['RSI'] <70) & (test_df['RSI'].shift(1) >= 70)) ## RSI 70 하향 돌파

  return buy, sell

## 테스트 데이터셋에 대해 매수/매도 신호 생성
test_df = df['2006':].copy()
buy, sell = make_signal(test_df)

def plot_signal(df, buy, sell):
  ## 매수/매도 신호를 차트에 표시하는 함수
  fig, ax1 = make_base_chart(df, "S&P500 구매 및 판매 시그널") ## 기본 차트 생성

  ## 매수/매도 신호 날짜 추출
  buy_dates = df.index[buy]
  sell_dates = df.index[sell] ## 매도 신호 날짜 추출

  ## 매수/매도 신호 산점도로 표시
  ax1.scatter(buy_dates, df.loc[buy_dates, 'Close'], marker='^', color='g', s=100, label='Buy Signal')
  ax1.scatter(sell_dates, df.loc[sell_dates, 'Close'], marker='v', color='r', s=100, label='Sell Signal')

  # 범례 업데이트
  handles, labels = ax1.get_legend_handles_labels()
  ax1.legend(handles=handles, labels=labels, loc='upper left')

  return fig, ax1

fig, ax1 = plot_signal(test_df, buy, sell)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MA50'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1271450742.py in <cell line: 0>()
#      17 ## 테스트 데이터셋에 대해 매수/매도 신호 생성
#      18 test_df = df['2006':].copy()
# ---> 19 buy, sell = make_signal(test_df)
#      20
#      21 def plot_signal(df, buy, sell):
#
# /tmp/ipython-input-1271450742.py in make_signal(df)
#       5 def make_signal(df):
#       6   ## 이동평균선과 RSI를 기반으로 매수/매도 신호를 생성하는 함수
# ----> 7   buy = ( (test_df['MA50'] > test_df['MA200']) & (test_df['MA50'].shift(1) <= test_df['MA200'].shift(1)) &
#       8          ## MA 골든 크로스 (현재 시점에서 50일 이동 평균이 200일 이동 평균보다 위에 있다. & 이전 시점에서는 50일 이동 평균이 200일 이동 평균보다 같거나 아래에 있었다.)
#       9         (test_df['RSI'] > 30) & (test_df['RSI'].shift(1) <= 30)) ## RSI 30 상향 돌파
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'MA50'

# %%
symbol = 'BITCOIN'
ticker = 'BTC-USD'

## 데이터 수집 날짜 설정 (2014년 1월 1일) ~ (2019년 12월 31일)
start_date = datetime.datetime(2015, 1, 1)
end_date = datetime.datetime(2025, 12, 31)

## yfinance를 사용하여 S&P 500 (^GSPC) 데이터를 지정된 기간 동안 다운로드
df = yf.download(ticker, start=start_date, end=end_date)

## MultiIndex 컬럼에서 두 번째 레벨(보통 'Adj Close' 등)을 제거하여 컬럼 이름을 단순화
df.columns = df.columns.droplevel(1)

## 다운로드된 DataFrame의 기술 통계량 출력
df.describe()
# Out:
# /tmp/ipython-input-282955146.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price          Close           High            Low           Open  \
# count    4017.000000    4017.000000    4017.000000    4017.000000
# mean    27532.109078   28065.656866   26925.972620   27511.225579
# std     31757.668213   32289.403099   31168.964464   31746.738605
# min       178.102997     211.731003     171.509995     176.897003
# 25%      3671.203613    3743.387939    3619.182129    3671.369873
# 50%     11358.101562   11569.914062   11012.415039   11349.740234
# 75%     42839.750000   43566.273438   41903.769531   42799.445312
# max    124752.531250  126198.070312  123196.046875  124752.140625
#
# Price        Volume
# count  4.017000e+03
# mean   2.219784e+10
# std    2.291288e+10
# min    7.860650e+06
# 25%    2.219410e+09
# 50%    1.777008e+10
# 75%    3.372362e+10
# max    3.509679e+11

# %%
plt.figure(figsize=(14, 7))
plt.grid(True)
plt.title('BITCOIN')
## 2018년까지의 데이터를 훈련 데이터로 시각화
plt.plot(df[:'2024'].index, df[:'2024']['Close'], label='Train Data')
## 2018년 이후 데이터를 훈련 데이터로 시각화
plt.plot(df['2024':].index, df['2024':]['Close'], label='Test Data')
plt.legend()
plt.show()
